# %% [markdown]
# <a href="https://colab.research.google.com/github/SaqlainHussainShah/implementation-of-sdi/blob/master/Deep_Learning_Separate_Notebook_A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Steps for implementation
# #### Reading CSV
# #### Data Description
# #### Data Cleaning
# #### Data Normalization
# #### Features
# #### Applying KNN and NB
# #### Confusion Matrix
# #### Deep Learning

# %%
#Importing Necessary Modules
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### Reading CSV

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
df1=pd.read_csv("/content/drive/My Drive/Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv")
df2=pd.read_csv("/content/drive/My Drive/Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv")
df3=pd.read_csv("/content/drive/My Drive/Friday-WorkingHours-Morning.pcap_ISCX.csv")
df4=pd.read_csv("/content/drive/My Drive/Monday-WorkingHours.pcap_ISCX.csv")
df5=pd.read_csv("/content/drive/My Drive/Thursday-WorkingHours-Afternoon-Infilteration.pcap_ISCX.csv")
df6=pd.read_csv("/content/drive/My Drive/Thursday-WorkingHours-Morning-WebAttacks.pcap_ISCX.csv")
df7=pd.read_csv("/content/drive/My Drive/Tuesday-WorkingHours.pcap_ISCX.csv")
df8=pd.read_csv("/content/drive/My Drive/Wednesday-workingHours.pcap_ISCX.csv")
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (20,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df=pd.concat([df1,df2,df3,df4,df5,df6,df7,df8])

# %%
del df1,df2,df3,df4,df5,df6,df7,df8

# %%
# category A attacks
df_bot=df[df[' Label']=='Bot']
df_ddos=df[df[' Label']=='DDoS']
df_golden_eye=df[df[' Label']=='DoS GoldenEye']
df_hulk=df[df[' Label']=='DoS Hulk']
df_ssh_patator=df[df[' Label']=='SSH-Patator']
df_ftp_patator=df[df[' Label']=='FTP-Patator']
df_infiltration=df[df[' Label']=='Infiltration']

# %%
# benign data
df_benign=df[df[' Label']=='BENIGN']

# %%
df_cat_A=pd.concat([df_bot,df_ddos,df_golden_eye,df_hulk,df_ssh_patator,df_infiltration,df_ftp_patator, df_benign])
df_cat_A.groupby(' Label').first()
# Out:
#                                                Flow ID  ...    Idle Min
#  Label                                                  ...
# BENIGN         192.168.10.5-104.16.207.165-54865-443-6  ...         0.0
# Bot              192.168.10.12-52.6.13.28-42544-8080-6  ...  10100000.0
# DDoS               172.16.0.1-192.168.10.50-49650-80-6  ...         0.0
# DoS GoldenEye      172.16.0.1-192.168.10.50-58958-80-6  ...         0.0
# DoS Hulk           172.16.0.1-192.168.10.50-50748-80-6  ...         0.0
# FTP-Patator        172.16.0.1-192.168.10.50-45422-80-6  ...         0.0
# Infiltration   192.168.10.8-205.174.165.73-53966-444-6  ...         0.0
# SSH-Patator        172.16.0.1-192.168.10.50-52358-22-6  ...         0.0
#
# [8 rows x 84 columns]

# %%
del df_bot,df_ddos,df_golden_eye,df_hulk,df_ssh_patator,df_ftp_patator,df_infiltration, df_benign

# %%
df=df_cat_A.copy()

# %%
del df_cat_A

# %%
df.groupby(' Label').first()
# Out:
#                                                Flow ID  ...    Idle Min
#  Label                                                  ...
# BENIGN         192.168.10.5-104.16.207.165-54865-443-6  ...         0.0
# Bot              192.168.10.12-52.6.13.28-42544-8080-6  ...  10100000.0
# DDoS               172.16.0.1-192.168.10.50-49650-80-6  ...         0.0
# DoS GoldenEye      172.16.0.1-192.168.10.50-58958-80-6  ...         0.0
# DoS Hulk           172.16.0.1-192.168.10.50-50748-80-6  ...         0.0
# FTP-Patator        172.16.0.1-192.168.10.50-45422-80-6  ...         0.0
# Infiltration   192.168.10.8-205.174.165.73-53966-444-6  ...         0.0
# SSH-Patator        172.16.0.1-192.168.10.50-52358-22-6  ...         0.0
#
# [8 rows x 84 columns]

# %%
# remove some data
df=df.iloc[0:-2000000]

# %% [markdown]
# ### Data Description

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 658327 entries, 24072 to 47843
# Data columns (total 85 columns):
# Flow ID                         658327 non-null object
#  Source IP                      658327 non-null object
#  Source Port                    658327 non-null int64
#  Destination IP                 658327 non-null object
#  Destination Port               658327 non-null int64
#  Protocol                       658327 non-null int64
#  Timestamp                      658327 non-null object
#  Flow Duration                  658327 non-null int64
#  Total Fwd Packets              658327 non-null int64
#  Total Backward Packets         658327 non-null int64
# Total Length of Fwd Packets     658327 non-null float64
#  Total Length of Bwd Packets    658327 non-null float64
#  Fwd Packet Length Max          658327 non-null float64
#  Fwd Packet Length Min          658327 non-null float64
#  Fwd Packet Length Mean         658327 non-null float64
#  Fwd Packet Length Std          658327 non-null float64
# Bwd Packet Length Max           658327 non-null float64
#  Bwd Packet Length Min          658327 non-null float64
#  Bwd Packet Length Mean         658327 non-null float64
#  Bwd Packet Length Std          658327 non-null float64
# Flow Bytes/s                    657351 non-null object
#  Flow Packets/s                 658327 non-null object
#  Flow IAT Mean                  658327 non-null float64
#  Flow IAT Std                   658327 non-null float64
#  Flow IAT Max                   658327 non-null float64
#  Flow IAT Min                   658327 non-null float64
# Fwd IAT Total                   658327 non-null float64
#  Fwd IAT Mean                   658327 non-null float64
#  Fwd IAT Std                    658327 non-null float64
#  Fwd IAT Max                    658327 non-null float64
#  Fwd IAT Min                    658327 non-null float64
# Bwd IAT Total                   658327 non-null float64
#  Bwd IAT Mean                   658327 non-null float64
#  Bwd IAT Std                    658327 non-null float64
#  Bwd IAT Max                    658327 non-null float64
#  Bwd IAT Min                    658327 non-null float64
# Fwd PSH Flags                   658327 non-null int64
#  Bwd PSH Flags                  658327 non-null int64
#  Fwd URG Flags                  658327 non-null int64
#  Bwd URG Flags                  658327 non-null int64
#  Fwd Header Length              658327 non-null int64
#  Bwd Header Length              658327 non-null int64
# Fwd Packets/s                   658327 non-null float64
#  Bwd Packets/s                  658327 non-null float64
#  Min Packet Length              658327 non-null float64
#  Max Packet Length              658327 non-null float64
#  Packet Length Mean             658327 non-null float64
#  Packet Length Std              658327 non-null float64
#  Packet Length Variance         658327 non-null float64
# FIN Flag Count                  658327 non-null int64
#  SYN Flag Count                 658327 non-null int64
#  RST Flag Count                 658327 non-null int64
#  PSH Flag Count                 658327 non-null int64
#  ACK Flag Count                 658327 non-null int64
#  URG Flag Count                 658327 non-null int64
#  CWE Flag Count                 658327 non-null int64
#  ECE Flag Count                 658327 non-null int64
#  Down/Up Ratio                  658327 non-null float64
#  Average Packet Size            658327 non-null float64
#  Avg Fwd Segment Size           658327 non-null float64
#  Avg Bwd Segment Size           658327 non-null float64
#  Fwd Header Length.1            658327 non-null int64
# Fwd Avg Bytes/Bulk              658327 non-null int64
#  Fwd Avg Packets/Bulk           658327 non-null int64
#  Fwd Avg Bulk Rate              658327 non-null int64
#  Bwd Avg Bytes/Bulk             658327 non-null int64
#  Bwd Avg Packets/Bulk           658327 non-null int64
# Bwd Avg Bulk Rate               658327 non-null int64
# Subflow Fwd Packets             658327 non-null int64
#  Subflow Fwd Bytes              658327 non-null int64
#  Subflow Bwd Packets            658327 non-null int64
#  Subflow Bwd Bytes              658327 non-null int64
# Init_Win_bytes_forward          658327 non-null int64
#  Init_Win_bytes_backward        658327 non-null int64
#  act_data_pkt_fwd               658327 non-null int64
#  min_seg_size_forward           658327 non-null int64
# Active Mean                     658327 non-null float64
#  Active Std                     658327 non-null float64
#  Active Max                     658327 non-null float64
#  Active Min                     658327 non-null float64
# Idle Mean                       658327 non-null float64
#  Idle Std                       658327 non-null float64
#  Idle Max                       658327 non-null float64
#  Idle Min                       658327 non-null float64
#  Label                          658327 non-null object
# dtypes: float64(43), int64(35), object(7)
# memory usage: 431.9+ MB

# %%
df.describe()
# Out:
#          Source Port   Destination Port  ...      Idle Max      Idle Min
# count  658327.000000      658327.000000  ...  6.583270e+05  6.583270e+05
# mean    41987.392838        5029.134907  ...  2.569256e+07  2.345661e+07
# std     19497.769340       15172.833796  ...  3.974592e+07  3.858482e+07
# min         0.000000           0.000000  ...  0.000000e+00  0.000000e+00
# 25%     35078.000000          80.000000  ...  0.000000e+00  0.000000e+00
# 50%     49294.000000          80.000000  ...  0.000000e+00  0.000000e+00
# 75%     56579.000000          80.000000  ...  6.890000e+07  1.670000e+07
# max     65535.000000       65532.000000  ...  1.200000e+08  1.200000e+08
#
# [8 rows x 78 columns]

# %%
df.columns
# Out:
# Index(['Flow ID', ' Source IP', ' Source Port', ' Destination IP',
#        ' Destination Port', ' Protocol', ' Timestamp', ' Flow Duration',
#        ' Total Fwd Packets', ' Total Backward Packets',
#        'Total Length of Fwd Packets', ' Total Length of Bwd Packets',
#        ' Fwd Packet Length Max', ' Fwd Packet Length Min',
#        ' Fwd Packet Length Mean', ' Fwd Packet Length Std',
#        'Bwd Packet Length Max', ' Bwd Packet Length Min',
#        ' Bwd Packet Length Mean', ' Bwd Packet Length Std', 'Flow Bytes/s',
#        ' Flow Packets/s', ' Flow IAT Mean', ' Flow IAT Std', ' Flow IAT Max',
#        ' Flow IAT Min', 'Fwd IAT Total', ' Fwd IAT Mean', ' Fwd IAT Std',
#        ' Fwd IAT Max', ' Fwd IAT Min', 'Bwd IAT Total', ' Bwd IAT Mean',
#        ' Bwd IAT Std', ' Bwd IAT Max', ' Bwd IAT Min', 'Fwd PSH Flags',
#        ' Bwd PSH Flags', ' Fwd URG Flags', ' Bwd URG Flags',
#        ' Fwd Header Length', ' Bwd Header Length', 'Fwd Packets/s',
#        ' Bwd Packets/s', ' Min Packet Length', ' Max Packet Length',
#        ' Packet Length Mean', ' Packet Length Std', ' Packet Length Variance',
#        'FIN Flag Count', ' SYN Flag Count', ' RST Flag Count',
#        ' PSH Flag Count', ' ACK Flag Count', ' URG Flag Count',
#        ' CWE Flag Count', ' ECE Flag Count', ' Down/Up Ratio',
#        ' Average Packet Size', ' Avg Fwd Segment Size',
#        ' Avg Bwd Segment Size', ' Fwd Header Length.1', 'Fwd Avg Bytes/Bulk',
#        ' Fwd Avg Packets/Bulk', ' Fwd Avg Bulk Rate', ' Bwd Avg Bytes/Bulk',
#        ' Bwd Avg Packets/Bulk', 'Bwd Avg Bulk Rate', 'Subflow Fwd Packets',
#        ' Subflow Fwd Bytes', ' Subflow Bwd Packets', ' Subflow Bwd Bytes',
#        'Init_Win_bytes_forward', ' Init_Win_bytes_backward',
#        ' act_data_pkt_fwd', ' min_seg_size_forward', 'Active Mean',
#        ' Active Std', ' Active Max', ' Active Min', 'Idle Mean', ' Idle Std',
#        ' Idle Max', ' Idle Min', ' Label'],
#       dtype='object')

# %% [markdown]
# ### Data Cleaning

# %%
df2=df[df.columns[7:-1]]
df2[' Label']=df[' Label']
df=df2
df2=[]
del df2
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
len(df.columns)
# Out:
# 78

# %%
df=df.dropna( axis=0, how='any')
df=df.replace(',,', np.nan, inplace=False)
df=df.drop(columns=[' Fwd Header Length.1'], axis=1, inplace=False)

# %%
df.replace("Infinity", 0, inplace=True)
df['Flow Bytes/s'].replace("Infinity", 0,inplace=True)
df[" Flow Packets/s"].replace("Infinity", 0, inplace=True)
df[" Flow Packets/s"].replace(np.nan, 0, inplace=True)
df['Flow Bytes/s'].replace(np.nan, 0,inplace=True)


df["Bwd Avg Bulk Rate"].replace("Infinity", 0, inplace=True)
df["Bwd Avg Bulk Rate"].replace(",,", 0, inplace=True)
df["Bwd Avg Bulk Rate"].replace(np.nan, 0, inplace=True)

df[" Bwd Avg Packets/Bulk"].replace("Infinity", 0, inplace=True)
df[" Bwd Avg Packets/Bulk"].replace(",,", 0, inplace=True)
df[" Bwd Avg Packets/Bulk"].replace(np.nan, 0, inplace=True)


df[" Bwd Avg Bytes/Bulk"].replace("Infinity", 0, inplace=True)
df[" Bwd Avg Bytes/Bulk"].replace(",,", 0, inplace=True)
df[" Bwd Avg Bytes/Bulk"].replace(np.nan, 0, inplace=True)


df[" Fwd Avg Bulk Rate"].replace("Infinity", 0, inplace=True)
df[" Fwd Avg Bulk Rate"].replace(",,", 0, inplace=True)
df[" Fwd Avg Bulk Rate"].replace(np.nan, 0, inplace=True)


df[" Fwd Avg Packets/Bulk"].replace("Infinity", 0, inplace=True)
df[" Fwd Avg Packets/Bulk"].replace(",,", 0, inplace=True)
df[" Fwd Avg Packets/Bulk"].replace(np.nan, 0, inplace=True)


df["Fwd Avg Bytes/Bulk"].replace("Infinity", 0, inplace=True)
df["Fwd Avg Bytes/Bulk"].replace(",,", 0, inplace=True)
df["Fwd Avg Bytes/Bulk"].replace(np.nan, 0, inplace=True)


df[" CWE Flag Count"].replace("Infinity", 0, inplace=True)
df[" CWE Flag Count"].replace(",,", 0, inplace=True)
df[" CWE Flag Count"].replace(np.nan, 0, inplace=True)

df[" Bwd URG Flags"].replace("Infinity", 0, inplace=True)
df[" Bwd URG Flags"].replace(",,", 0, inplace=True)
df[" Bwd URG Flags"].replace(np.nan, 0, inplace=True)

df[" Bwd PSH Flags"].replace("Infinity", 0, inplace=True)
df[" Bwd PSH Flags"].replace(",,", 0, inplace=True)
df[" Bwd PSH Flags"].replace(np.nan, 0, inplace=True)

df[" Fwd URG Flags"].replace("Infinity", 0, inplace=True)
df[" Fwd URG Flags"].replace(",,", 0, inplace=True)
df[" Fwd URG Flags"].replace(np.nan, 0, inplace=True)

# %%
df["Flow Bytes/s"]=df["Flow Bytes/s"].astype("float64")
df[' Flow Packets/s']=df[" Flow Packets/s"].astype("float64")

# %%
df['Bwd Avg Bulk Rate']=df["Bwd Avg Bulk Rate"].astype("float64")
df[' Bwd Avg Packets/Bulk']=df[" Bwd Avg Packets/Bulk"].astype("float64")
df[' Bwd Avg Bytes/Bulk']=df[" Bwd Avg Bytes/Bulk"].astype("float64")
df[' Fwd Avg Bulk Rate']=df[" Fwd Avg Bulk Rate"].astype("float64")
df[' Fwd Avg Packets/Bulk']=df[" Fwd Avg Packets/Bulk"].astype("float64")
df['Fwd Avg Bytes/Bulk']=df["Fwd Avg Bytes/Bulk"].astype("float64")
df[' CWE Flag Count']=df[" CWE Flag Count"].astype("float64")
df[' Bwd URG Flags']=df[" Bwd URG Flags"].astype("float64")
df[' Bwd PSH Flags']=df[" Bwd PSH Flags"].astype("float64")
df[' Fwd URG Flags']=df[" Fwd URG Flags"].astype("float64")

# %%
pd.set_option('display.max_rows', df.shape[0])

# %%
df.replace('Infinity',0.0, inplace=True)

# %%
df.replace('NaN',0.0, inplace=True)

# %%
df.columns
# Out:
# Index([' Flow Duration', ' Total Fwd Packets', ' Total Backward Packets',
#        'Total Length of Fwd Packets', ' Total Length of Bwd Packets',
#        ' Fwd Packet Length Max', ' Fwd Packet Length Min',
#        ' Fwd Packet Length Mean', ' Fwd Packet Length Std',
#        'Bwd Packet Length Max', ' Bwd Packet Length Min',
#        ' Bwd Packet Length Mean', ' Bwd Packet Length Std', 'Flow Bytes/s',
#        ' Flow Packets/s', ' Flow IAT Mean', ' Flow IAT Std', ' Flow IAT Max',
#        ' Flow IAT Min', 'Fwd IAT Total', ' Fwd IAT Mean', ' Fwd IAT Std',
#        ' Fwd IAT Max', ' Fwd IAT Min', 'Bwd IAT Total', ' Bwd IAT Mean',
#        ' Bwd IAT Std', ' Bwd IAT Max', ' Bwd IAT Min', 'Fwd PSH Flags',
#        ' Bwd PSH Flags', ' Fwd URG Flags', ' Bwd URG Flags',
#        ' Fwd Header Length', ' Bwd Header Length', 'Fwd Packets/s',
#        ' Bwd Packets/s', ' Min Packet Length', ' Max Packet Length',
#        ' Packet Length Mean', ' Packet Length Std', ' Packet Length Variance',
#        'FIN Flag Count', ' SYN Flag Count', ' RST Flag Count',
#        ' PSH Flag Count', ' ACK Flag Count', ' URG Flag Count',
#        ' CWE Flag Count', ' ECE Flag Count', ' Down/Up Ratio',
#        ' Average Packet Size', ' Avg Fwd Segment Size',
#        ' Avg Bwd Segment Size', 'Fwd Avg Bytes/Bulk', ' Fwd Avg Packets/Bulk',
#        ' Fwd Avg Bulk Rate', ' Bwd Avg Bytes/Bulk', ' Bwd Avg Packets/Bulk',
#        'Bwd Avg Bulk Rate', 'Subflow Fwd Packets', ' Subflow Fwd Bytes',
#        ' Subflow Bwd Packets', ' Subflow Bwd Bytes', 'Init_Win_bytes_forward',
#        ' Init_Win_bytes_backward', ' act_data_pkt_fwd',
#        ' min_seg_size_forward', 'Active Mean', ' Active Std', ' Active Max',
#        ' Active Min', 'Idle Mean', ' Idle Std', ' Idle Max', ' Idle Min',
#        ' Label'],
#       dtype='object')

# %%
X=df[df.columns[0:-1]]
y=df[df.columns[-1]]

del df

# %% [markdown]
# ### Data Normalization

# %%
from scipy import stats

# %%
cols = list(X.columns)
for col in cols:
    X[col] = stats.zscore(X[col])
# Out:
# /usr/local/lib/python3.6/dist-packages/scipy/stats/stats.py:2315: RuntimeWarning: invalid value encountered in true_divide
#   return (a - mns) / sstd

# %%
X.head()
# Out:
#         Flow Duration   Total Fwd Packets  ...   Idle Max   Idle Min
# 24072        0.727275            0.002332  ...  -0.390581  -0.346903
# 24677       -0.695047           -0.011214  ...  -0.647101  -0.608542
# 56376       -0.693228           -0.006134  ...  -0.647101  -0.608542
# 56401       -0.696414           -0.011214  ...  -0.647101  -0.608542
# 56596       -0.693395           -0.006134  ...  -0.647101  -0.608542
#
# [5 rows x 76 columns]

# %% [markdown]
# ### Feature Selection

# %%
features=[" Fwd Packet Length Max"," Flow IAT Std"," Fwd Packet Length Std" ,"Fwd IAT Total",' Flow Packets/s',' Flow Duration', " Fwd Packet Length Mean", " Total Length of Bwd Packets", "Flow Bytes/s", "Total Length of Fwd Packets", " Flow IAT Mean", " Bwd Packet Length Mean",  " Flow IAT Max", " Bwd Packet Length Std", ' Total Fwd Packets', ' Total Backward Packets']

# %%
X=X[features].copy()
X.head()
# Out:
#         Fwd Packet Length Max  ...   Total Backward Packets
# 24072               -0.002125  ...                 0.001388
# 24677               -0.282786  ...                -0.008660
# 56376               -0.113692  ...                -0.006148
# 56401               -0.277557  ...                -0.008660
# 56596               -0.113692  ...                -0.006148
#
# [5 rows x 16 columns]

# %%
len(X.columns)
# Out:
# 16

# %% [markdown]
# ### Applying Algorithms

# %%
from sklearn.model_selection import train_test_split     # import module for train test split

# %%
X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=0.2, random_state=10)

# %% [markdown]
# #### KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
t1=time.time()

for i in range(1,len(X_train.columns)+1):
    knn=KNeighborsClassifier(n_neighbors=i)
    model_knn=knn.fit(X_train,y_train)
    yhat=model_knn.predict(X_test)
    print("for " , i,  " as K, accuracy is : ", accuracy_score(y_test, yhat))
t2=time.time()
print(" time for ", i ," k's :: ", (t2-t1)/60 , " minutes")
# Out:
# for  1  as K, accuracy is :  0.9818195162158398
# for  2  as K, accuracy is :  0.981853389387159
# for  3  as K, accuracy is :  0.9850280582769094
# for  4  as K, accuracy is :  0.9831198696259272
# for  5  as K, accuracy is :  0.9830652961832463
# for  6  as K, accuracy is :  0.9818439801729038
# for  7  as K, accuracy is :  0.9831575064829486
# for  8  as K, accuracy is :  0.9818515075443079
# for  9  as K, accuracy is :  0.9830765872403527
# for  10  as K, accuracy is :  0.9830765872403527
# for  11  as K, accuracy is :  0.9829523856121823
# for  12  as K, accuracy is :  0.9829599129835865
# for  13  as K, accuracy is :  0.9829636766692887
# for  14  as K, accuracy is :  0.982944858240778
# for  15  as K, accuracy is :  0.9828545297839268
# for  16  as K, accuracy is :  0.9828846392695438
#  time for  16  k's ::  146.24801788727441  minutes

# %%
import pickle
filename = 'drive/My Drive/model_cat_A.sav'

# %%
pickle.dump(model_knn, open(filename, 'wb'))

# %%
# to load model
model_knn = pickle.load(open(filename, 'rb'))
y_hat=model_knn.predict(X_test)

# %% [markdown]
# #### Naive Bayes

# %% [markdown]
# ##### Gaussian Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

# %%
t1=time.time()

gnb = GaussianNB()
model_gnb = gnb.fit(X_train, y_train)
yhat_gnb=model_gnb.predict(X_test)

print("Accuracy :: ", accuracy_score(y_test,yhat))

t2=time.time()
print(" time for Naive Baye's :: ", (t2-t1) , " seconds")
# Out:
# Accuracy ::  0.9828846392695438
#  time for Naive Baye's ::  6.311462879180908  seconds

# %% [markdown]
# ##### Bernoulli Naive Bayes

# %%
from sklearn.naive_bayes import BernoulliNB

# %%
clf = BernoulliNB()
clf.fit(X_train, y_train)
yhat_bnb=clf.predict(X_test)
print("Accuracy ::: ", accuracy_score(y_test,yhat_bnb))
# Out:
# Accuracy :::  0.8195726711253797

# %% [markdown]
# ### Confusion Matrix

# %%
y_test_arr=y_test.as_matrix()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   """Entry point for launching an IPython kernel.

# %%
true={}
false={}
not_detected={}

for x in range(len(y_test_arr)):
    if y_test_arr[x]==yhat[x]:
      if y_test_arr[x] in true:
        true[y_test_arr[x]]=true[y_test_arr[x]]+1
      else:
        true[y_test_arr[x]]=1
    elif y_test_arr[x]!=yhat[x]:
      if yhat[x] in false:
        false[yhat[x]]=false[yhat[x]]+1

        if y_test_arr[x] in not_detected:
          not_detected[y_test_arr[x]]=not_detected[y_test_arr[x]]+1
        else:
          not_detected[y_test_arr[x]]=1

      else:
        false[yhat[x]]=1

        if y_test_arr[x] in not_detected:
          not_detected[y_test_arr[x]]=not_detected[y_test_arr[x]]+1
        else:
          not_detected[y_test_arr[x]]=1

# %%
true
# Out:
# {'BENIGN': 449720,
#  'Bot': 143,
#  'DDoS': 25334,
#  'DoS GoldenEye': 1984,
#  'DoS Hulk': 42897,
#  'FTP-Patator': 1618,
#  'SSH-Patator': 603}

# %%
false
# Out:
# {'BENIGN': 4142,
#  'Bot': 28,
#  'DDoS': 121,
#  'DoS GoldenEye': 112,
#  'DoS Hulk': 4685,
#  'FTP-Patator': 7}

# %%
not_detected
# Out:
# {'BENIGN': 4943,
#  'Bot': 219,
#  'DDoS': 54,
#  'DoS GoldenEye': 72,
#  'DoS Hulk': 3187,
#  'FTP-Patator': 32,
#  'Infiltration': 3,
#  'SSH-Patator': 585}

# %% [markdown]
# ## Deep Learning

# %%
import keras
from keras import backend as k
from keras.models import Sequential
from keras.layers import Activation

# %%
from keras.layers.core import Dense
from keras.optimizers import Adam
from keras.metrics import categorical_crossentropy

# %%
model=Sequential([
    Dense(32,input_shape=(16,), activation='relu'),
    Dense(64, activation='relu'),
    Dense(8, activation='softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_7 (Dense)              (None, 32)                544
# _________________________________________________________________
# dense_8 (Dense)              (None, 64)                2112
# _________________________________________________________________
# dense_9 (Dense)              (None, 8)                 520
# =================================================================
# Total params: 3,176
# Trainable params: 3,176
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(Adam(lr=0.0001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
def prepare_targets(y_train, y_test):
	le.fit(y_train)
	y_train_enc = le.transform(y_train)
	y_test_enc = le.transform(y_test)
	return y_train_enc, y_test_enc

# %%
y_train_enc, y_test_enc = prepare_targets(y_train, y_test)

# %%
t1=time.time()


model.fit(X_train,y_train_enc,batch_size=20,epochs=20,shuffle=True,verbose=2)
t2=time.time()
print(" time taken for 20 epochs :: ", (t2-t1)/60 , " minutes")
# Out:
# Epoch 1/20
#  - 67s - loss: 0.1255 - acc: 0.9553
# Epoch 2/20
#  - 68s - loss: 0.1216 - acc: 0.9564
# Epoch 3/20
#  - 67s - loss: 0.1177 - acc: 0.9577
# Epoch 4/20
#  - 67s - loss: 0.1142 - acc: 0.9586
# Epoch 5/20
#  - 67s - loss: 0.1110 - acc: 0.9595
# Epoch 6/20
#  - 67s - loss: 0.1079 - acc: 0.9616
# Epoch 7/20
#  - 67s - loss: 0.1050 - acc: 0.9633
# Epoch 8/20
#  - 67s - loss: 0.1021 - acc: 0.9642
# Epoch 9/20
#  - 66s - loss: 0.0993 - acc: 0.9650
# Epoch 10/20
#  - 67s - loss: 0.0971 - acc: 0.9652
# Epoch 11/20
#  - 67s - loss: 0.0953 - acc: 0.9658
# Epoch 12/20
#  - 67s - loss: 0.0936 - acc: 0.9661
# Epoch 13/20
#  - 67s - loss: 0.0921 - acc: 0.9667
# Epoch 14/20
#  - 66s - loss: 0.0908 - acc: 0.9669
# Epoch 15/20
#  - 66s - loss: 0.0895 - acc: 0.9675
# Epoch 16/20
#  - 67s - loss: 0.0884 - acc: 0.9677
# Epoch 17/20
#  - 66s - loss: 0.0874 - acc: 0.9678
# Epoch 18/20
#  - 67s - loss: 0.0864 - acc: 0.9684
# Epoch 19/20
#  - 67s - loss: 0.0854 - acc: 0.9687
# Epoch 20/20
#  - 67s - loss: 0.0846 - acc: 0.9690
#  time taken for 20 epochs ::  22.309582885106405  minutes

# %%
yhat=model.predict_classes(X_test,batch_size=10,verbose=0)

# %%
def calculate_confusion_matrix(y_test_arr,yhat):
  true={}
  false={}
  not_detected={}

  for x in range(len(y_test_arr)):
      if y_test_arr[x]==yhat[x]:
        if y_test_arr[x] in true:
          true[y_test_arr[x]]=true[y_test_arr[x]]+1
        else:
          true[y_test_arr[x]]=1
      elif y_test_arr[x]!=yhat[x]:
        if yhat[x] in false:
          false[yhat[x]]=false[yhat[x]]+1

          if y_test_arr[x] in not_detected:
            not_detected[y_test_arr[x]]=not_detected[y_test_arr[x]]+1
          else:
            not_detected[y_test_arr[x]]=1

        else:
          false[yhat[x]]=1

          if y_test_arr[x] in not_detected:
            not_detected[y_test_arr[x]]=not_detected[y_test_arr[x]]+1
          else:
            not_detected[y_test_arr[x]]=1
            
  print("========================================")
  print(" True values :: ", true)
  print(" False values :: ", false)
  print(" not detected values :: ", not_detected)    
  print("========================================")

# %%
  calculate_confusion_matrix(y_test_enc,yhat)
# Out:
# ========================================
#  True values ::  {2: 25515, 4: 44516, 0: 53186, 5: 1617, 3: 1954, 7: 593, 1: 143}
#  False values ::  {0: 2489, 4: 1315, 3: 94, 1: 25, 7: 1, 5: 3, 2: 20}
#  not detected values ::  {4: 1521, 0: 1282, 1: 299, 7: 585, 2: 178, 3: 47, 5: 31, 6: 4}
# ========================================

# %% [markdown]
# #### Validation set

# %%
model_val=Sequential([
    Dense(32,input_shape=(16,), activation='relu'),
    Dense(64, activation='relu'),
    Dense(8, activation='softmax')
])

# %%
model_val.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_10 (Dense)             (None, 32)                544
# _________________________________________________________________
# dense_11 (Dense)             (None, 64)                2112
# _________________________________________________________________
# dense_12 (Dense)             (None, 8)                 520
# =================================================================
# Total params: 3,176
# Trainable params: 3,176
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_val.compile(Adam(lr=0.0001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
t1=time.time()


model_val.fit(X_train,y_train_enc,validation_split=0.1,batch_size=20,epochs=20,shuffle=True,verbose=2)
t2=time.time()
print(" time taken for 20 epochs :: ", (t2-t1)/60 , " minutes")
# Out:
# Train on 473292 samples, validate on 52588 samples
# Epoch 1/20
#  - 64s - loss: 0.4093 - acc: 0.8620 - val_loss: 0.2649 - val_acc: 0.9063
# Epoch 2/20
#  - 64s - loss: 0.2324 - acc: 0.9219 - val_loss: 0.2013 - val_acc: 0.9433
# Epoch 3/20
#  - 64s - loss: 0.1896 - acc: 0.9400 - val_loss: 0.1749 - val_acc: 0.9419
# Epoch 4/20
#  - 64s - loss: 0.1693 - acc: 0.9432 - val_loss: 0.1595 - val_acc: 0.9454
# Epoch 5/20
#  - 63s - loss: 0.1564 - acc: 0.9460 - val_loss: 0.1493 - val_acc: 0.9469
# Epoch 6/20
#  - 65s - loss: 0.1465 - acc: 0.9496 - val_loss: 0.1397 - val_acc: 0.9540
# Epoch 7/20
#  - 64s - loss: 0.1391 - acc: 0.9517 - val_loss: 0.1325 - val_acc: 0.9551
# Epoch 8/20
#  - 64s - loss: 0.1334 - acc: 0.9529 - val_loss: 0.1292 - val_acc: 0.9521
# Epoch 9/20
#  - 64s - loss: 0.1289 - acc: 0.9540 - val_loss: 0.1257 - val_acc: 0.9590
# Epoch 10/20
#  - 64s - loss: 0.1248 - acc: 0.9560 - val_loss: 0.1201 - val_acc: 0.9624
# Epoch 11/20
#  - 64s - loss: 0.1211 - acc: 0.9570 - val_loss: 0.1158 - val_acc: 0.9581
# Epoch 12/20
#  - 64s - loss: 0.1181 - acc: 0.9579 - val_loss: 0.1138 - val_acc: 0.9576
# Epoch 13/20
#  - 64s - loss: 0.1155 - acc: 0.9584 - val_loss: 0.1119 - val_acc: 0.9633
# Epoch 14/20
#  - 64s - loss: 0.1130 - acc: 0.9592 - val_loss: 0.1094 - val_acc: 0.9613
# Epoch 15/20
#  - 64s - loss: 0.1108 - acc: 0.9596 - val_loss: 0.1083 - val_acc: 0.9606
# Epoch 16/20
#  - 65s - loss: 0.1088 - acc: 0.9603 - val_loss: 0.1048 - val_acc: 0.9639
# Epoch 17/20
#  - 64s - loss: 0.1068 - acc: 0.9613 - val_loss: 0.1078 - val_acc: 0.9618
# Epoch 18/20
#  - 64s - loss: 0.1049 - acc: 0.9619 - val_loss: 0.1061 - val_acc: 0.9637
# Epoch 19/20
#  - 63s - loss: 0.1029 - acc: 0.9633 - val_loss: 0.1010 - val_acc: 0.9688
# Epoch 20/20
#  - 64s - loss: 0.1012 - acc: 0.9643 - val_loss: 0.0993 - val_acc: 0.9689
#  time taken for 20 epochs ::  21.352197992801667  minutes

# %%
yhat_val=model_val.predict
