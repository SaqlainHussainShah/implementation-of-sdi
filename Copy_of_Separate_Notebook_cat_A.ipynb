# %% [markdown]
# <a href="https://colab.research.google.com/github/SaqlainHussainShah/implementation-of-sdi/blob/master/Copy_of_Separate_Notebook_cat_A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Steps for implementation
# #### Reading CSV
# #### Data Description
# #### Data Cleaning
# #### Data Normalization
# #### Features
# #### Applying KNN and NB
# #### Confusion Matrix

# %%
#Importing Necessary Modules
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### Reading CSV

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
df1=pd.read_csv("/content/drive/My Drive/Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv")
df2=pd.read_csv("/content/drive/My Drive/Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv")
df3=pd.read_csv("/content/drive/My Drive/Friday-WorkingHours-Morning.pcap_ISCX.csv")
df4=pd.read_csv("/content/drive/My Drive/Monday-WorkingHours.pcap_ISCX.csv")
df5=pd.read_csv("/content/drive/My Drive/Thursday-WorkingHours-Afternoon-Infilteration.pcap_ISCX.csv")
df6=pd.read_csv("/content/drive/My Drive/Thursday-WorkingHours-Morning-WebAttacks.pcap_ISCX.csv")
df7=pd.read_csv("/content/drive/My Drive/Tuesday-WorkingHours.pcap_ISCX.csv")
df8=pd.read_csv("/content/drive/My Drive/Wednesday-workingHours.pcap_ISCX.csv")
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (20,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df=pd.concat([df1,df2,df3,df4,df5,df6,df7,df8])

# %%
del df1,df2,df3,df4,df5,df6,df7,df8

# %%
# category A attacks
df_bot=df[df[' Label']=='Bot']
df_ddos=df[df[' Label']=='DDoS']
df_golden_eye=df[df[' Label']=='DoS GoldenEye']
df_hulk=df[df[' Label']=='DoS Hulk']
df_ssh_patator=df[df[' Label']=='SSH-Patator']
df_ftp_patator=df[df[' Label']=='FTP-Patator']
df_infiltration=df[df[' Label']=='Infiltration']

# %%
# benign data
df_benign=df[df[' Label']=='BENIGN']

# %%
df_cat_A=pd.concat([df_bot,df_ddos,df_golden_eye,df_hulk,df_ssh_patator,df_ftp_patator,df_infiltration])
df_cat_A.groupby(' Label').first()
# Out:
#                                                Flow ID  ...    Idle Min
#  Label                                                  ...
# Bot              192.168.10.12-52.6.13.28-42544-8080-6  ...  10100000.0
# DDoS               172.16.0.1-192.168.10.50-49650-80-6  ...         0.0
# DoS GoldenEye      172.16.0.1-192.168.10.50-58958-80-6  ...         0.0
# DoS Hulk           172.16.0.1-192.168.10.50-50748-80-6  ...         0.0
# FTP-Patator        172.16.0.1-192.168.10.50-45422-80-6  ...         0.0
# Infiltration   192.168.10.8-205.174.165.73-53966-444-6  ...         0.0
# SSH-Patator        172.16.0.1-192.168.10.50-52358-22-6  ...         0.0
#
# [7 rows x 84 columns]

# %%
del df_bot,df_ddos,df_golden_eye,df_hulk,df_ssh_patator,df_ftp_patator,df_infiltration

# %%
df=df_cat_A.copy()

# %%
del df_cat_A

# %%
df.groupby(' Label').first()
# Out:
#                                                Flow ID  ...    Idle Min
#  Label                                                  ...
# Bot              192.168.10.12-52.6.13.28-42544-8080-6  ...  10100000.0
# DDoS               172.16.0.1-192.168.10.50-49650-80-6  ...         0.0
# DoS GoldenEye      172.16.0.1-192.168.10.50-58958-80-6  ...         0.0
# DoS Hulk           172.16.0.1-192.168.10.50-50748-80-6  ...         0.0
# FTP-Patator        172.16.0.1-192.168.10.50-45422-80-6  ...         0.0
# Infiltration   192.168.10.8-205.174.165.73-53966-444-6  ...         0.0
# SSH-Patator        172.16.0.1-192.168.10.50-52358-22-6  ...         0.0
#
# [7 rows x 84 columns]

# %% [markdown]
# ### Data Description

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 385230 entries, 24072 to 224706
# Data columns (total 85 columns):
# Flow ID                         385230 non-null object
#  Source IP                      385230 non-null object
#  Source Port                    385230 non-null int64
#  Destination IP                 385230 non-null object
#  Destination Port               385230 non-null int64
#  Protocol                       385230 non-null int64
#  Timestamp                      385230 non-null object
#  Flow Duration                  385230 non-null int64
#  Total Fwd Packets              385230 non-null int64
#  Total Backward Packets         385230 non-null int64
# Total Length of Fwd Packets     385230 non-null float64
#  Total Length of Bwd Packets    385230 non-null float64
#  Fwd Packet Length Max          385230 non-null float64
#  Fwd Packet Length Min          385230 non-null float64
#  Fwd Packet Length Mean         385230 non-null float64
#  Fwd Packet Length Std          385230 non-null float64
# Bwd Packet Length Max           385230 non-null float64
#  Bwd Packet Length Min          385230 non-null float64
#  Bwd Packet Length Mean         385230 non-null float64
#  Bwd Packet Length Std          385230 non-null float64
# Flow Bytes/s                    384281 non-null object
#  Flow Packets/s                 385230 non-null object
#  Flow IAT Mean                  385230 non-null float64
#  Flow IAT Std                   385230 non-null float64
#  Flow IAT Max                   385230 non-null float64
#  Flow IAT Min                   385230 non-null float64
# Fwd IAT Total                   385230 non-null float64
#  Fwd IAT Mean                   385230 non-null float64
#  Fwd IAT Std                    385230 non-null float64
#  Fwd IAT Max                    385230 non-null float64
#  Fwd IAT Min                    385230 non-null float64
# Bwd IAT Total                   385230 non-null float64
#  Bwd IAT Mean                   385230 non-null float64
#  Bwd IAT Std                    385230 non-null float64
#  Bwd IAT Max                    385230 non-null float64
#  Bwd IAT Min                    385230 non-null float64
# Fwd PSH Flags                   385230 non-null int64
#  Bwd PSH Flags                  385230 non-null int64
#  Fwd URG Flags                  385230 non-null int64
#  Bwd URG Flags                  385230 non-null int64
#  Fwd Header Length              385230 non-null int64
#  Bwd Header Length              385230 non-null int64
# Fwd Packets/s                   385230 non-null float64
#  Bwd Packets/s                  385230 non-null float64
#  Min Packet Length              385230 non-null float64
#  Max Packet Length              385230 non-null float64
#  Packet Length Mean             385230 non-null float64
#  Packet Length Std              385230 non-null float64
#  Packet Length Variance         385230 non-null float64
# FIN Flag Count                  385230 non-null int64
#  SYN Flag Count                 385230 non-null int64
#  RST Flag Count                 385230 non-null int64
#  PSH Flag Count                 385230 non-null int64
#  ACK Flag Count                 385230 non-null int64
#  URG Flag Count                 385230 non-null int64
#  CWE Flag Count                 385230 non-null int64
#  ECE Flag Count                 385230 non-null int64
#  Down/Up Ratio                  385230 non-null float64
#  Average Packet Size            385230 non-null float64
#  Avg Fwd Segment Size           385230 non-null float64
#  Avg Bwd Segment Size           385230 non-null float64
#  Fwd Header Length.1            385230 non-null int64
# Fwd Avg Bytes/Bulk              385230 non-null int64
#  Fwd Avg Packets/Bulk           385230 non-null int64
#  Fwd Avg Bulk Rate              385230 non-null int64
#  Bwd Avg Bytes/Bulk             385230 non-null int64
#  Bwd Avg Packets/Bulk           385230 non-null int64
# Bwd Avg Bulk Rate               385230 non-null int64
# Subflow Fwd Packets             385230 non-null int64
#  Subflow Fwd Bytes              385230 non-null int64
#  Subflow Bwd Packets            385230 non-null int64
#  Subflow Bwd Bytes              385230 non-null int64
# Init_Win_bytes_forward          385230 non-null int64
#  Init_Win_bytes_backward        385230 non-null int64
#  act_data_pkt_fwd               385230 non-null int64
#  min_seg_size_forward           385230 non-null int64
# Active Mean                     385230 non-null float64
#  Active Std                     385230 non-null float64
#  Active Max                     385230 non-null float64
#  Active Min                     385230 non-null float64
# Idle Mean                       385230 non-null float64
#  Idle Std                       385230 non-null float64
#  Idle Max                       385230 non-null float64
#  Idle Min                       385230 non-null float64
#  Label                          385230 non-null object
# dtypes: float64(43), int64(35), object(7)
# memory usage: 252.8+ MB

# %%
df.describe()
# Out:
#          Source Port   Destination Port  ...      Idle Max      Idle Min
# count  385230.000000      385230.000000  ...  3.852300e+05  3.852300e+05
# mean    46674.761524         168.689819  ...  3.953782e+07  3.673961e+07
# std     11326.888964        1868.772121  ...  4.475617e+07  4.422704e+07
# min        80.000000          21.000000  ...  0.000000e+00  0.000000e+00
# 25%     38778.000000          80.000000  ...  0.000000e+00  0.000000e+00
# 50%     48914.000000          80.000000  ...  6.164915e+06  6.040616e+06
# 75%     55690.000000          80.000000  ...  8.560000e+07  8.540000e+07
# max     65532.000000       64873.000000  ...  1.200000e+08  1.200000e+08
#
# [8 rows x 78 columns]

# %%
df.columns
# Out:
# Index(['Flow ID', ' Source IP', ' Source Port', ' Destination IP',
#        ' Destination Port', ' Protocol', ' Timestamp', ' Flow Duration',
#        ' Total Fwd Packets', ' Total Backward Packets',
#        'Total Length of Fwd Packets', ' Total Length of Bwd Packets',
#        ' Fwd Packet Length Max', ' Fwd Packet Length Min',
#        ' Fwd Packet Length Mean', ' Fwd Packet Length Std',
#        'Bwd Packet Length Max', ' Bwd Packet Length Min',
#        ' Bwd Packet Length Mean', ' Bwd Packet Length Std', 'Flow Bytes/s',
#        ' Flow Packets/s', ' Flow IAT Mean', ' Flow IAT Std', ' Flow IAT Max',
#        ' Flow IAT Min', 'Fwd IAT Total', ' Fwd IAT Mean', ' Fwd IAT Std',
#        ' Fwd IAT Max', ' Fwd IAT Min', 'Bwd IAT Total', ' Bwd IAT Mean',
#        ' Bwd IAT Std', ' Bwd IAT Max', ' Bwd IAT Min', 'Fwd PSH Flags',
#        ' Bwd PSH Flags', ' Fwd URG Flags', ' Bwd URG Flags',
#        ' Fwd Header Length', ' Bwd Header Length', 'Fwd Packets/s',
#        ' Bwd Packets/s', ' Min Packet Length', ' Max Packet Length',
#        ' Packet Length Mean', ' Packet Length Std', ' Packet Length Variance',
#        'FIN Flag Count', ' SYN Flag Count', ' RST Flag Count',
#        ' PSH Flag Count', ' ACK Flag Count', ' URG Flag Count',
#        ' CWE Flag Count', ' ECE Flag Count', ' Down/Up Ratio',
#        ' Average Packet Size', ' Avg Fwd Segment Size',
#        ' Avg Bwd Segment Size', ' Fwd Header Length.1', 'Fwd Avg Bytes/Bulk',
#        ' Fwd Avg Packets/Bulk', ' Fwd Avg Bulk Rate', ' Bwd Avg Bytes/Bulk',
#        ' Bwd Avg Packets/Bulk', 'Bwd Avg Bulk Rate', 'Subflow Fwd Packets',
#        ' Subflow Fwd Bytes', ' Subflow Bwd Packets', ' Subflow Bwd Bytes',
#        'Init_Win_bytes_forward', ' Init_Win_bytes_backward',
#        ' act_data_pkt_fwd', ' min_seg_size_forward', 'Active Mean',
#        ' Active Std', ' Active Max', ' Active Min', 'Idle Mean', ' Idle Std',
#        ' Idle Max', ' Idle Min', ' Label'],
#       dtype='object')

# %% [markdown]
# ### Data Cleaning

# %%
df2=df[df.columns[7:-1]]
df2[' Label']=df[' Label']
df=df2
df2=[]
del df2
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
len(df.columns)
# Out:
# 78

# %%
df=df.dropna( axis=0, how='any')
df=df.replace(',,', np.nan, inplace=False)
df=df.drop(columns=[' Fwd Header Length.1'], axis=1, inplace=False)

# %%
df.replace("Infinity", 0, inplace=True)
df['Flow Bytes/s'].replace("Infinity", 0,inplace=True)
df[" Flow Packets/s"].replace("Infinity", 0, inplace=True)
df[" Flow Packets/s"].replace(np.nan, 0, inplace=True)
df['Flow Bytes/s'].replace(np.nan, 0,inplace=True)


df["Bwd Avg Bulk Rate"].replace("Infinity", 0, inplace=True)
df["Bwd Avg Bulk Rate"].replace(",,", 0, inplace=True)
df["Bwd Avg Bulk Rate"].replace(np.nan, 0, inplace=True)

df[" Bwd Avg Packets/Bulk"].replace("Infinity", 0, inplace=True)
df[" Bwd Avg Packets/Bulk"].replace(",,", 0, inplace=True)
df[" Bwd Avg Packets/Bulk"].replace(np.nan, 0, inplace=True)


df[" Bwd Avg Bytes/Bulk"].replace("Infinity", 0, inplace=True)
df[" Bwd Avg Bytes/Bulk"].replace(",,", 0, inplace=True)
df[" Bwd Avg Bytes/Bulk"].replace(np.nan, 0, inplace=True)


df[" Fwd Avg Bulk Rate"].replace("Infinity", 0, inplace=True)
df[" Fwd Avg Bulk Rate"].replace(",,", 0, inplace=True)
df[" Fwd Avg Bulk Rate"].replace(np.nan, 0, inplace=True)


df[" Fwd Avg Packets/Bulk"].replace("Infinity", 0, inplace=True)
df[" Fwd Avg Packets/Bulk"].replace(",,", 0, inplace=True)
df[" Fwd Avg Packets/Bulk"].replace(np.nan, 0, inplace=True)


df["Fwd Avg Bytes/Bulk"].replace("Infinity", 0, inplace=True)
df["Fwd Avg Bytes/Bulk"].replace(",,", 0, inplace=True)
df["Fwd Avg Bytes/Bulk"].replace(np.nan, 0, inplace=True)


df[" CWE Flag Count"].replace("Infinity", 0, inplace=True)
df[" CWE Flag Count"].replace(",,", 0, inplace=True)
df[" CWE Flag Count"].replace(np.nan, 0, inplace=True)

df[" Bwd URG Flags"].replace("Infinity", 0, inplace=True)
df[" Bwd URG Flags"].replace(",,", 0, inplace=True)
df[" Bwd URG Flags"].replace(np.nan, 0, inplace=True)

df[" Bwd PSH Flags"].replace("Infinity", 0, inplace=True)
df[" Bwd PSH Flags"].replace(",,", 0, inplace=True)
df[" Bwd PSH Flags"].replace(np.nan, 0, inplace=True)

df[" Fwd URG Flags"].replace("Infinity", 0, inplace=True)
df[" Fwd URG Flags"].replace(",,", 0, inplace=True)
df[" Fwd URG Flags"].replace(np.nan, 0, inplace=True)

# %%
df["Flow Bytes/s"]=df["Flow Bytes/s"].astype("float64")
df[' Flow Packets/s']=df[" Flow Packets/s"].astype("float64")

# %%
df['Bwd Avg Bulk Rate']=df["Bwd Avg Bulk Rate"].astype("float64")
df[' Bwd Avg Packets/Bulk']=df[" Bwd Avg Packets/Bulk"].astype("float64")
df[' Bwd Avg Bytes/Bulk']=df[" Bwd Avg Bytes/Bulk"].astype("float64")
df[' Fwd Avg Bulk Rate']=df[" Fwd Avg Bulk Rate"].astype("float64")
df[' Fwd Avg Packets/Bulk']=df[" Fwd Avg Packets/Bulk"].astype("float64")
df['Fwd Avg Bytes/Bulk']=df["Fwd Avg Bytes/Bulk"].astype("float64")
df[' CWE Flag Count']=df[" CWE Flag Count"].astype("float64")
df[' Bwd URG Flags']=df[" Bwd URG Flags"].astype("float64")
df[' Bwd PSH Flags']=df[" Bwd PSH Flags"].astype("float64")
df[' Fwd URG Flags']=df[" Fwd URG Flags"].astype("float64")

# %%
pd.set_option('display.max_rows', df.shape[0])

# %%
df.replace('Infinity',0.0, inplace=True)

# %%
df.replace('NaN',0.0, inplace=True)

# %%
df.columns
# Out:
# Index([' Flow Duration', ' Total Fwd Packets', ' Total Backward Packets',
#        'Total Length of Fwd Packets', ' Total Length of Bwd Packets',
#        ' Fwd Packet Length Max', ' Fwd Packet Length Min',
#        ' Fwd Packet Length Mean', ' Fwd Packet Length Std',
#        'Bwd Packet Length Max', ' Bwd Packet Length Min',
#        ' Bwd Packet Length Mean', ' Bwd Packet Length Std', 'Flow Bytes/s',
#        ' Flow Packets/s', ' Flow IAT Mean', ' Flow IAT Std', ' Flow IAT Max',
#        ' Flow IAT Min', 'Fwd IAT Total', ' Fwd IAT Mean', ' Fwd IAT Std',
#        ' Fwd IAT Max', ' Fwd IAT Min', 'Bwd IAT Total', ' Bwd IAT Mean',
#        ' Bwd IAT Std', ' Bwd IAT Max', ' Bwd IAT Min', 'Fwd PSH Flags',
#        ' Bwd PSH Flags', ' Fwd URG Flags', ' Bwd URG Flags',
#        ' Fwd Header Length', ' Bwd Header Length', 'Fwd Packets/s',
#        ' Bwd Packets/s', ' Min Packet Length', ' Max Packet Length',
#        ' Packet Length Mean', ' Packet Length Std', ' Packet Length Variance',
#        'FIN Flag Count', ' SYN Flag Count', ' RST Flag Count',
#        ' PSH Flag Count', ' ACK Flag Count', ' URG Flag Count',
#        ' CWE Flag Count', ' ECE Flag Count', ' Down/Up Ratio',
#        ' Average Packet Size', ' Avg Fwd Segment Size',
#        ' Avg Bwd Segment Size', 'Fwd Avg Bytes/Bulk', ' Fwd Avg Packets/Bulk',
#        ' Fwd Avg Bulk Rate', ' Bwd Avg Bytes/Bulk', ' Bwd Avg Packets/Bulk',
#        'Bwd Avg Bulk Rate', 'Subflow Fwd Packets', ' Subflow Fwd Bytes',
#        ' Subflow Bwd Packets', ' Subflow Bwd Bytes', 'Init_Win_bytes_forward',
#        ' Init_Win_bytes_backward', ' act_data_pkt_fwd',
#        ' min_seg_size_forward', 'Active Mean', ' Active Std', ' Active Max',
#        ' Active Min', 'Idle Mean', ' Idle Std', ' Idle Max', ' Idle Min',
#        ' Label'],
#       dtype='object')

# %%
X=df[df.columns[0:-1]]
y=df[df.columns[-1]]

del df

# %% [markdown]
# ### Data Normalization

# %%
from scipy import stats

# %%
cols = list(X.columns)
for col in cols:
    X[col] = stats.zscore(X[col])
# Out:
# /usr/local/lib/python3.6/dist-packages/scipy/stats/stats.py:2315: RuntimeWarning: invalid value encountered in true_divide
#   return (a - mns) / sstd

# %%
X.head()
# Out:
#         Flow Duration   Total Fwd Packets  ...   Idle Max   Idle Min
# 24072        0.431697            0.228316  ...  -0.657509   -0.60416
# 24677       -0.905756           -0.251889  ...  -0.885350   -0.83244
# 56376       -0.904046           -0.071812  ...  -0.885350   -0.83244
# 56401       -0.907041           -0.251889  ...  -0.885350   -0.83244
# 56596       -0.904202           -0.071812  ...  -0.885350   -0.83244
#
# [5 rows x 76 columns]

# %% [markdown]
# ### Feature Selection

# %%
features=[" Fwd Packet Length Max"," Flow IAT Std"," Fwd Packet Length Std" ,"Fwd IAT Total",' Flow Packets/s',' Flow Duration', " Fwd Packet Length Mean", " Total Length of Bwd Packets", "Flow Bytes/s", "Total Length of Fwd Packets", " Flow IAT Mean", " Bwd Packet Length Mean",  " Flow IAT Max", " Bwd Packet Length Std", ' Total Fwd Packets', ' Total Backward Packets']

# %%
X=X[features].copy()
X.head()
# Out:
#         Fwd Packet Length Max  ...   Total Backward Packets
# 24072                0.671840  ...                 0.282979
# 24677               -0.670543  ...                -0.190918
# 56376                0.138222  ...                -0.072444
# 56401               -0.645530  ...                -0.190918
# 56596                0.138222  ...                -0.072444
#
# [5 rows x 16 columns]

# %%
len(X.columns)
# Out:
# 16

# %% [markdown]
# ### Applying Algorithms

# %%
from sklearn.model_selection import train_test_split     # import module for train test split

# %%
X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=0.2, random_state=10)

# %% [markdown]
# #### KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
t1=time.time()

for i in range(1,len(X_train.columns)):
    knn=KNeighborsClassifier(n_neighbors=i)
    model_knn=knn.fit(X_train,y_train)
    yhat=model_knn.predict(X_test)
    print("for " , i,  " as K, accuracy is : ", accuracy_score(y_test, yhat))
t2=time.time()
print(" time for ", i ," k's :: ", (t2-t1)/60 , " minutes")
# Out:
# for  1  as K, accuracy is :  0.9994275082295692
# for  2  as K, accuracy is :  0.9991802958741559
# for  3  as K, accuracy is :  0.9995446088189756
# for  4  as K, accuracy is :  0.9994014858763678
# for  5  as K, accuracy is :  0.9993624523465657
# for  6  as K, accuracy is :  0.9993104076401629
# for  7  as K, accuracy is :  0.9992583629337601
# for  8  as K, accuracy is :  0.9992323405805587
# for  9  as K, accuracy is :  0.9992323405805587
# for  10  as K, accuracy is :  0.999219329403958
# for  11  as K, accuracy is :  0.9991152399911524
# for  12  as K, accuracy is :  0.999089217637951
# for  13  as K, accuracy is :  0.9990631952847496
# for  14  as K, accuracy is :  0.9990111505783468
# for  15  as K, accuracy is :  0.9990631952847496
#  time for  15  k's ::  3.5256566047668456  minutes

# %% [markdown]
# #### Naive Bayes

# %% [markdown]
# ##### Gaussian Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

# %%
t1=time.time()

gnb = GaussianNB()
model_gnb = gnb.fit(X_train, y_train)
y_hat=model_gnb.predict(X_test)

print("Accuracy :: ", accuracy_score(y_test,yhat))

t2=time.time()
print(" time for Naive Baye's :: ", (t2-t1) , " seconds")
# Out:
# Accuracy ::  0.9845743863065649
#  time for Naive Baye's ::  7.548450469970703  seconds

# %% [markdown]
# ##### Bernoulli Naive Bayes

# %%
from sklearn.naive_bayes import BernoulliNB

# %%
clf = BernoulliNB()
clf.fit(X_train, y_train)
yhat_bnb=clf.predict(X_test)
print("Accuracy ::: ", accuracy_score(y_test,yhat_bnb))
# Out:
# Accuracy :::  0.7385297511650059

# %% [markdown]
# ### Confusion Matrix

# %%
y_test_arr=y_test.as_matrix()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   """Entry point for launching an IPython kernel.

# %%
true={}
false={}
not_detected={}

for x in range(len(y_test_arr)):
    if y_test_arr[x]==yhat[x]:
      if y_test_arr[x] in true:
        true[y_test_arr[x]]=true[y_test_arr[x]]+1
      else:
        true[y_test_arr[x]]=1
    elif y_test_arr[x]!=yhat[x]:
      if yhat[x] in false:
        false[yhat[x]]=false[yhat[x]]+1

        if y_test_arr[x] in not_detected:
          not_detected[y_test_arr[x]]=not_detected[y_test_arr[x]]+1
        else:
          not_detected[y_test_arr[x]]=1

      else:
        false[yhat[x]]=1

        if y_test_arr[x] in not_detected:
          not_detected[y_test_arr[x]]=not_detected[y_test_arr[x]]+1
        else:
          not_detected[y_test_arr[x]]=1

# %%
true
# Out:
# {'BENIGN': 448216,
#  'Bot': 169,
#  'DDoS': 25478,
#  'DoS GoldenEye': 1962,
#  'DoS Hulk': 44662,
#  'DoS Slowhttptest': 1075,
#  'DoS slowloris': 1135,
#  'FTP-Patator': 1573,
#  'Heartbleed': 3,
#  'Infiltration': 2,
#  'PortScan': 31988,
#  'SSH-Patator': 646,
#  'Web Attack-Brute Force': 200,
#  'Web Attack-XSS': 39}

# %%
false
# Out:
# {'BENIGN': 2095,
#  'Bot': 45,
#  'DDoS': 45,
#  'DoS GoldenEye': 79,
#  'DoS Hulk': 5654,
#  'DoS Slowhttptest': 53,
#  'DoS slowloris': 18,
#  'FTP-Patator': 6,
#  'Infiltration': 1,
#  'PortScan': 283,
#  'SSH-Patator': 287,
#  'Web Attack-Brute Force': 90,
#  'Web Attack-XSS': 73}

# %%
not_detected
# Out:
# {'BENIGN': 6437,
#  'Bot': 196,
#  'DDoS': 54,
#  'DoS GoldenEye': 48,
#  'DoS Hulk': 1157,
#  'DoS Slowhttptest': 23,
#  'DoS slowloris': 12,
#  'FTP-Patator': 27,
#  'Infiltration': 5,
#  'PortScan': 32,
#  'SSH-Patator': 529,
#  'Web Attack-Brute Force': 112,
#  'Web Attack-Sql Injection': 3,
#  'Web Attack-XSS': 94}
